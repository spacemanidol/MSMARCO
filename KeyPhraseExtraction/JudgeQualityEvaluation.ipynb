# %%
import numpy as np
import random
import re
files = ['100k.tsv']

# %%
urls, judgements, p = {}, {}, []
for file in files:
    with open(file,'r') as f:
        for l in f:
            l = l.strip().split('\t')
            if l[14] not in urls:
                urls[l[14]] = 0
            urls[l[14]] += 1
for file in files:
    with open(file,'r') as f:
        for l in f:
            l = l.strip().split('\t')
            if urls[l[14]] > 1 and len(l) > 16:
                if l[14] not in judgements and 'error' not in l[16].strip().lower():
                    judgements[l[14]] = []
                if 'error' not in l[16].strip().lower(): 
                    currentJudgements = []
                    for phrase in l[16]:
                        currentJudgements.append(set(re.sub(' +', ' ',phrase.strip()).split(' ')))
                    judgements[l[14]].append(currentJudgements)

# %%
def getScoreUnigram(candidate, gold):
    #Unigram Levenshtein distance
    #First we produce all possible pairs and greedily select 
    scoring, bestMatch = {}, {}
    maxScore = 0
    maxLabel = ''
    #Generate all possible combinations
    for goldLabel in gold:
        goldKey = str(goldLabel)
        scoring[goldKey] = {}
        for candidateLabel in candidate:
            candidateKey = str(candidateLabel)
            scoring[goldKey][candidateKey] = (len(goldLabel) - len(goldLabel-candidateLabel))/len(goldLabel)
    #Greedily select best combination and then remove all related combinations.
    while len(scoring) > 0:
        maxScore = 0
        maxLabel = ''
        for goldLabel in scoring:
            goldKey = str(goldLabel)
            for candidateLabel in scoring[goldKey]:
                candidateKey = str(candidateLabel)
                score = scoring[goldKey][candidateKey]
                if score >= maxScore:
                    maxScore = score
                    maxLabel = (goldKey, candidateKey)
        bestMatch[maxLabel] = scoring[maxLabel[0]][maxLabel[1]]
        scoring.pop(maxLabel[0])#remove all pairs that could
    return sum(bestMatch.values())/len(gold)

# %%
def getScoreEM(candidate, gold):
    #Unigram Levenshtein distance
    #First we produce all possible pairs and greedily select 
    scoring, bestMatch = {}, {}
    maxScore = 0
    maxLabel = ''
    #Generate all possible combinations
    for goldLabel in gold:
        goldKey = str(goldLabel)
        scoring[goldKey] = {}
        for candidateLabel in candidate:
            candidateKey = str(candidateLabel)
            if goldLabel == candidateLabel:
                scoring[goldKey][candidateKey] = 1
            else:
                scoring[goldKey][candidateKey] = 0
    #Greedily select best combination and then remove all related combinations.
    while len(scoring) > 0:
        maxScore = -1
        maxLabel = ''
        for goldLabel in scoring:
            goldKey = str(goldLabel)
            for candidateLabel in scoring[goldKey]:
                candidateKey = str(candidateLabel)
                score = scoring[goldKey][candidateKey]
                if score >= maxScore:
                    maxScore = score
                    maxLabel = (goldKey, candidateKey)
        bestMatch[maxLabel] = scoring[maxLabel[0]][maxLabel[1]]
        scoring.pop(maxLabel[0])#remove all pairs that could
    return sum(bestMatch.values())/len(gold)

# %%
#Boostrapping 
randomEM = []
randomUnigram = []
for i in range(10000):
    scoresUnigram = []
    scoresEM = []
    for url in judgements:
        goldIndex = random.randrange(0,len(judgements[url]))
        for i in range(len(judgements[url])):
            if goldIndex != i:
                scoresUnigram.append(getScoreUnigram(judgements[url][goldIndex],judgements[url][i]))
                scoresEM.append(getScoreEM(judgements[url][goldIndex],judgements[url][i]))
    randomEM.append(np.mean(scoresEM))
    randomUnigram.append(np.mean(scoresUnigram))
print('Exact Match max:{} min:{} mean:{}'.format(np.max(randomEM), np.min(randomEM),np.mean(randomEM)))
print('Unigram max:{} min:{} mean:{}'.format(np.max(randomUnigram), np.min(randomUnigram),np.mean(randomUnigram)))
# Out:
# Exact Match max:0.4976190476190476 min:0.36428571428571427 mean:0.4356185714285715
# Unigram max:0.6449074074074074 min:0.5028174603174603 mean:0.5772240595238094

# %%
#First Judge as Gold
scoresUnigram = []
scoresEM = []
for url in judgements:
    for i in range(len(judgements[url][1:])):
            scoresUnigram.append(getScoreUnigram(judgements[url][0],judgements[url][i]))
            scoresEM.append(getScoreEM(judgements[url][0],judgements[url][i]))
print('Exact Match max:{} min:{} mean:{}'.format(np.max(scoresEM), np.min(scoresEM),np.mean(scoresEM)))
print('Unigram max:{} min:{} mean:{}'.format(np.max(scoresUnigram), np.min(scoresUnigram),np.mean(scoresUnigram)))
# Out:
# Exact Match max:1.0 min:0.0 mean:0.6829388356726032
# Unigram max:1.0 min:0.0 mean:0.6829388356726032

# %%
#Highest Agreement
#This form tends to skew towards a perfect score not because judges always get it right but because the judge with the highest agreement tended to only submit a single keyphrase. Since we are selecting the best match greedily judges tend to have agreement with this single keyphrase in at least one of their other keyphrases
scoresEM = []
scoresUnigram
for url in judgements:
    goldIndex = random.randrange(0,len(judgements[url]))
    maxScore = 0
    maxSequence = []
    for i in range(len(judgements[url])):
        currentRuns = []
        for j in range(len(judgements[url])):
            if j != i:
                currentRuns.append(getScoreUnigram(judgements[url][i],judgements[url][j]))
            if len(currentRuns) > 0:
                currentScore = np.mean(currentRuns)
                if maxScore < currentScore:
                    maxScore = currentScore
                    maxSequence = currentRuns
    scoresUnigram += maxSequence
for url in judgements:
    goldIndex = random.randrange(0,len(judgements[url]))
    maxScore = 0
    maxSequence = []
    for i in range(len(judgements[url])):
        currentRuns = []
        for j in range(len(judgements[url])):
            if j != i:
                currentRuns.append(getScoreEM(judgements[url][i],judgements[url][j]))
            currentScore = np.mean(currentRuns)
            if maxScore < currentScore:
                maxScore = currentScore
                maxSequence = currentRuns
    scoresEM += maxSequence
print('Exact Match max:{} min:{} mean:{}'.format(np.max(scoresEM), np.min(scoresEM),np.mean(scoresEM)))
print('Unigram max:{} min:{} mean:{}'.format(np.max(scoresUnigram), np.min(scoresUnigram),np.mean(scoresUnigram)))
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# Exact Match max:1.0 min:0.0 mean:0.5466988727858293
# Unigram max:1.0 min:0.0 mean:0.704047619047619
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
#Pariwise
scoresUnigram = []
scoresEM = []
for url in judgements:
    for i in range(len(judgements[url])):
        currentRuns = []
        for j in range(len(judgements[url])):
            if j != i:
                currentRuns.append(getScoreUnigram(judgements[url][i],judgements[url][j]))
        if len(currentRuns) > 0:
            scoresUnigram.append(np.sum(currentRuns)/(len(judgements[url])-1))
for url in judgements:
    for i in range(len(judgements[url])):
        currentRuns = []
        for j in range(len(judgements[url])):
            if j != i:
                currentRuns.append(getScoreEM(judgements[url][i],judgements[url][j]))
        if len(currentRuns) > 0:
            scoresEM.append(np.sum(currentRuns)/(len(judgements[url])-1))
print('Exact Match max:{} min:{} mean:{}'.format(np.max(scoresEM), np.min(scoresEM),np.mean(scoresEM)))
print('Unigram max:{} min:{} mean:{}'.format(np.max(scoresUnigram), np.min(scoresUnigram),np.mean(scoresUnigram)))
# Out:
# Exact Match max:1.0 min:0.0 mean:0.43513257575757575
# Unigram max:1.0 min:0.0 mean:0.5766466750841751

# %%
judgements
# Out:
# {'http://getfit.jillianmichaels.com/long-lose-10-1500calorie-diet-1224.html': [[{'loss',
#     'weight'},
#    {'Metabolic'}],
#   [{'caloric'}, {'loss', 'weight'}],
#   [{'calorie', 'diet'}, {'Basal', 'Metabolic', 'Rate'}, {'USDA'}],
#   [{'loss', 'weight'}, {'calorie', 'diet'}, {'Exercise'}],
#   [{'loss', 'weight'}, {'caloric', 'intake'}, {'Basal', 'Metabolic', 'Rate'}]],
#  'http://www.terradiversa.com/tour/chorro-waterfall-yunguilla-valley/': [[{'Chorro',
#     'Waterfall'},
#    {'Valley', 'Yunguilla'},
#    {'historic', 'site'}],
#   [{'Chorro', 'Waterfall'}, {'Valley', 'Yunguilla'}],
#   [{'Chorro', 'Waterfall'}, {'Valley', 'Yunguilla'}, {'TerraDiversa'}],
#   [{'Chorro', 'Waterfall'}, {'Valley', 'Yunguilla'}, {'Ecuador'}],
#   [{'Chorro', 'Waterfall'}, {'Valley', 'Yunguilla'}]],
#  'https://www.mapquest.com/us/or/hillsboro-282040229': [[{'Holiday', 'Inn'},
#    {'Hillsboro'},
#    {'OR'}],
#   [{'Hillsboro'}, {'U.S.', 'state'}, {'County', 'Washington'}],
#   [{'Holiday', 'Inn'}, {'Washington'}, {'U.S'}],
#   [{'Holiday', 'Inn'}, {'Hillsboro'}],
#   [{'Hillsboro'}, {'Oregon'}, {'Tualatin', 'Valley'}]],
#  'https://www.howmuchisit.org/how-much-does-urgent-care-cost/': [[{'Care',
#     'Cost',
#     'Urgent'},
#    {'clinic', 'physician-staffed'},
#    {'medical', 'services'}],
#   [{'care', 'cost', 'urgent'}, {'medical', 'services'}],
#   [{'Care', 'Urgent'},
#    {'clinic', 'physician-staffed'},
#    {'medical', 'services', 'walk-in'}],
#   [{'Care', 'Urgent'},
#    {'clinic', 'physician-staffed'},
#    {'medical', 'services', 'walk-in'}],
#   [{'Care', 'Cost', 'Urgent'},
#    {'clinic', 'physician-staffed'},
#    {'medical', 'services', 'walk-in'}]],
#  'https://www.omahaschoolofmusicanddance.com/what-is-lyrical-dance-15-interesting-facts-about-this-contemporary-style/': [[{'Dance',
#     'Lyrical'},
#    {'Facts'},
#    {'Contemporary'}],
#   [{'Dance', 'Lyrical'}, {'Contemporary', 'Style'}],
#   [{'Dance', 'Lyrical'},
#    {'Contemporary', 'Style'},
#    {'dancing', 'jazz', 'techniques'}],
#   [{'Dance', 'Lyrical'}, {'Contemporary', 'Style'}, {'choreographer'}],
#   [{'Dance', 'Lyrical'}, {'Contemporary', 'Style'}]],
#  'https://www2.illinois.gov/cms/benefits/Pages/default.aspx': [[{'Bureau'}],
#   [{'Benefits', 'Bureau', 'of'},
#    {'Central', 'Managem\xad\xad\xad\xad\xadent', 'Services'}],
#   [{'Bureau'}, {'Portal\u200b\u200b', 'Web'}, {'Illinois', 'State', 'of'}],
#   [{'Illinois', 'State', 'of'},
#    {'Benefits', 'Bureau', 'of'},
#    {'Central', 'Managem\xad\xad\xad\xad\xadent', 'Services'}],
#   [{'Benefits', 'Bureau', 'of'},
#    {'Department', 'Illinois', 'The'},
#    {'Government', 'Health', 'Plan'}]],
#  'https://simpletire.com/hercules-avalanche-x-tremesuvtires': [[{'Tire'},
#    {'Avalanche', 'X-Treme'}],
#   [{'Avalanche', 'X-Treme'}, {'SUV'}],
#   [{'Tire'}, {'Hercules'}],
#   [{'Hercules'}, {'Avalanche', 'X-Treme'}],
#   [{'Results', 'Tire'}, {'Hercules'}, {'Avalanche', 'X-Treme'}]],
#  'http://www.imdb.com/title/tt0082862/': [[{'Othello'},
#    {'Moorish', 'general'},
#    {'Venetian', 'state'}],
#   [{'Othello', 'The', 'Tragedy', 'of'}, {'Moor', 'Venice', 'of', 'the'}],
#   [{'Othello'}, {'Tragedy'}, {'Moor', 'Venice', 'of', 'the'}],
#   [{'Othello'}, {'Moorish', 'general'}, {'Venetian', 'state'}],
#   [{'Othello'}, {'Tragedy'}]],
#  'http://www.dictionary.com/browse/syntax': [[{'syntax'}, {'Dictionary'}],
#   [{'syntax'}, {'dictionary'}],
#   [{'syntax'}],
#   [{'syntax'}, {'Dictionary'}]],
#  'https://leehs.fcps.edu/contact': [[{'HS', 'Lee'}, {'MacDonald', 'Matthew'}],
#   [{'High', 'Lee', 'School'},
#    {'County', 'Fairfax', 'Public', 'Schools'},
#    {'Contact', 'Us'}],
#   [{'County', 'Fairfax', 'Public', 'Schools'}, {'Virginia'}, {'Directory'}],
#   [{'contacts'}, {'numbers', 'phone'}, {'High', 'Lee', 'School'}],
#   [{'High', 'Lee', 'School'}, {'Virginia'}]],
#  'https://pethelpful.com/dogs/Top-10-Dog-Breeds-Ideal-for-Catching-Rats': [[{'Breeds',
#     'Dog'},
#    {'Cairn', 'Terrier'},
#    {'Rats'}],
#   [{'Breeds', 'Dog'}, {'Catching', 'Rats'}, {'Rat', 'Terrier'}],
#   [{'Breeds', 'Dog'}, {'Catching', 'Rats'}, {'Cairn', 'Terrier'}],
#   [{'Breeds', 'Dog'}, {'Catching', 'Rats'}],
#   [{'Breeds', 'Dog'}, {'Catching', 'Rats'}, {'Rat', 'Terrier'}]],
#  'http://traveltips.usatoday.com/tsa-carry-rules-laptop-computers-62914.html': [[{'Computers',
#     'Laptop'},
#    {'Rules'}],
#   [{'Administration', 'Security', 'Transportation'},
#    {'computer', 'laptop'},
#    {'Carry', 'On', 'Rules'}],
#   [{'TSA'}, {'Computers', 'Laptop'}],
#   [{'TSA'}],
#   [{'Computers', 'Laptop'}, {'TSA'}]],
#  'https://weather.com/weather/tenday/l/Baconton+GA+31716:4:US': [[{'Baconton'},
#    {'Weather'}],
#   [{'Weather'}, {'Baconton'}],
#   [{'Baconton,', 'GA'}, {'Weather'}],
#   [{'Baconton'}, {'Weather'}],
#   [{'Baconton,', 'GA'}, {'10', 'Day', 'Weather'}]],
#  'https://quizlet.com/8136549/rnaprotein-synthesis-flash-cards/': [[{'Protein',
#     'Synthesis'}],
#   [{'Protein', 'Synthesis'}, {'RNA'}],
#   [{'RNA'}, {'Protein', 'Synthesis'}],
#   [{'Protein'}, {'Synthesis'}],
#   [{'RNA/Protein', 'Synthesis'}, {'RNA', 'generating'}, {'template'}]],
#  'https://legal-dictionary.thefreedictionary.com/regulation': [[{'regulation'},
#    {'Dictionary'}],
#   [{'regulation'}, {'superior'}],
#   [{'regulation'}],
#   [{'regulation'}, {'bureaucracy', 'the'}],
#   [{'regulation'}]],
#  'http://floridasnursing.gov/nursing-faqs/renewal/': [[{'Board',
#     'Florida',
#     'Nursing',
#     'of'},
#    {'Health'}],
#   [{'FAQs', 'Renewal'}, {'Department', 'Florida', 'Health', 'of'}],
#   [{'Board', 'Nursing', 'of'}, {'Florida'}],
#   [{'CEBroker'}, {'CPR/AED', 'certification'}]],
#  'http://www.al.com/news/index.ssf/2017/12/will_roy_moore_concede_what_ha.html': [[{'Moore.',
#     'Roy'},
#    {'Republican', 'Senate'},
#    {'ballots', 'provisional'}],
#   [{'Moore', 'Roy'}, {'Republican', 'Senate'}],
#   [{'Moore', 'Roy'}, {'concede'}, {'What', 'happens'}],
#   [{'Moore', 'Roy'}, {'Republican', 'Senate'}, {'Alabama', 'Secretary'}],
#   [{'Moore', 'Roy'}, {'Republican', 'Senate', 'candidate'}]],
#  'http://www.dictionary.com/browse/yank': [[{'yank'}],
#   [{'yank'}, {'verb'}],
#   [{'yank'}, {'definitions'}],
#   [{'yank'}, {'definitions'}],
#   [{'yank'}]],
#  'http://endgeoengineering.com/geoengineering.html': [[{'Geoengineering'},
#    {"Earth's", 'atmosphere.'},
#    {'barium', 'toxicity'}],
#   [{'Chemtrails'}, {'Geoengineering'}],
#   [{'Geoengineering'}, {'Chemtrails'}, {'aerial', 'operation'}],
#   [{'Geoengineering'}, {'Chemtrails'}]],
#  'https://support.apple.com/en-us/HT202645': [[{'SIM', 'card'},
#    {'iPhone'},
#    {'Cellular', 'model'}],
#   [{'SIM', 'card'}, {'iPhone'}, {'iPad'}],
#   [{'Micro-SIM'}, {'Nano-SIM'}, {'SIM', 'card'}],
#   [{'Nano'}, {'Micro'}, {'SIM', 'card'}],
#   [{'Nano-SIM', 'card'}, {'Micro-SIM'}, {'SIM', 'card'}]],
#  'http://www.yourarticlelibrary.com/sociology/the-contribution-of-emile-durkheim-towards-sociology-1198-words/6250/': [[{'Durkheim',
#     'Emile'},
#    {'France'},
#    {'Sociology', 'of', 'science'}],
#   [{'Contribution', 'Durkheim”', 'The', 'of', '“Emile'},
#    {'Sociology'},
#    {'dominant', 'force'}],
#   [{'Durkheim', 'Emile'}, {'Sociology'}],
#   [{'Durkheim', 'Emile'}, {'Sociologists', 'contemporary'}],
#   [{'Durkheim', 'Emile'}, {'Contribution'}, {'Sociology'}]],
#  'https://answers.yahoo.com/question/index?qid=20080510221546AApbFe6': [[{'college',
#     'make',
#     'professors/teachers'}],
#   [{'college', 'professors'}, {'salary'}],
#   [{'college', 'professors'}, {'teachers'}, {'Salaries'}],
#   [{'professors'}, {'salary'}],
#   [{'college', 'professors'},
#    {'music', 'teacher'},
#    {'&', 'Education', 'Reference'}]],
#  'http://bodyandhealth.canada.com/drug/getdrug/flonase': [[{'Flonase'}],
#   [{'Flonase'}, {'DIN'}, {'allergic', 'rhinitis'}],
#   [{'Flonase'}, {'medication'}, {'allergic', 'rhinitis'}],
#   [{'Flonase'}, {'DIN'}],
#   [{'Flonase'},
#    {'Drug', 'Identification', 'Number'},
#    {'allergic', 'rhinitis', 'seasonal'}]],
#  'https://www.tripzilla.com/summer-korea-fantastic-things-special-season/36845': [[{'Do',
#     'Things',
#     'to'},
#    {'Korea'},
#    {'Festival', 'Music'}],
#   [{'Korea'},
#    {'Festival', 'Music', 'Summer'},
#    {'Boryeong', 'Festival', 'Mud'}],
#   [{'Summer'}, {'Korea'}, {'Fantastic', 'Things'}],
#   [{'Korea'}, {'Summer'}, {'Festival', 'Music'}],
#   [{'Korea'},
#    {'Halla', 'Hike', 'Mountain', 'Trail', 'a', 'on'},
#    {'Beach', 'Get', 'Glorious', 'Tan', 'a', 'at', 'the'}]],
#  'http://blackpantheranimal.com/black-panther-food.php': [[{'Black',
#     'panthers'},
#    {'diet'}],
#   [{'Black', 'Food', 'Panther'}, {'carnivores'}, {'flesh', 'human'}],
#   [{'Black', 'Food', 'Panther'}, {'carnivores'}, {'eaters', 'meat'}],
#   [{'Black', 'Food', 'Panther'}, {'carnivores'}],
#   [{'Black', 'Food', 'Panther'}, {'eaters', 'meat'}]],
#  'http://www.holiday-weather.com/madrid/averages/may/': [[{'Madrid'},
#    {'Spain'},
#    {'Averages', 'May', 'Weather'}],
#   [{'Weather'}, {'Madrid'}, {'Spain'}],
#   [{'average', 'temperature'}, {'Madrid,', 'Spain'}, {'May'}],
#   [{'Averages', 'Weather'}, {'RAINFALL'}, {'Madrid'}],
#   [{'Averages', 'May', 'Weather'}, {'Madrid'}, {'Spain'}]],
#  'http://www.truckingtruth.com/cdl-training-program/page1/who-is-required-to-get-a-cdl': [[{'Act',
#     'Commercial',
#     'Motor',
#     'Safety',
#     'Vehicle'},
#    {'CDL', 'Nationwide'},
#    {'Gross', 'Rating', 'Vehicle', 'Weight'}],
#   [{'CDL'},
#    {'Act', 'Commercial', 'Motor', 'Safety', 'Vehicle'},
#    {'suspensions'}],
#   [{'CMVSA'}, {'driverʼs', 'license'}, {'GVWR'}],
#   [{'CMVSA'}, {'CDL'}],
#   [{'Commercial'}, {'Motor', 'Vehicle'}, {'Act', 'Safety'}]],
#  'http://www.countyoffice.org/kettering-oh-treasurer-tax-collector/': [[{'Kettering',
#     'Treasurer'},
#    {'Collector', 'Office', 'Tax'}],
#   [{'&', 'Collector', 'Kettering', 'Office', 'Tax', 'Treasurer'}, {'Ohio'}],
#   [{'Kettering', 'Treasurer'}, {'Collector', 'Office', 'Tax'}, {'Ohio'}],
#   [{'Kettering', 'Treasurer'}, {'Collector', 'Office', 'Tax'}],
#   [{'Kettering', 'Treasurer'}, {'Collector', 'Office', 'Tax'}]],
#  'https://createartwithme.com/shop/lesson-plans-worksheets/tempera-painting-techniques-lesson-plan-worksheet/': [[{'Tempera'},
#    {'Painting', 'Techniques'}],
#   [{'Painting', 'Tempera'}, {'Lesson', 'Techniques'}],
#   [{'Painting', 'Tempera'},
#    {'paint', 'tempera', '“school”'},
#    {'Acrylic', 'Painting'}],
#   [{'Painting', 'Techniques', 'Tempera'}, {'Lesson', 'Plan'}, {'Worksheet'}],
#   [{'Painting', 'Technique', 'Tempera'}, {'Worksheet'}]],
#  'http://wnep.com/2016/09/17/pennsylvanias-new-red-light-law-goes-into-effect-sunday/': [[{'Pennsylvania'},
#    {'Law', 'Light', 'Red'}],
#   [{'Law', 'Light', 'Red'}, {'Pennsylvania'}],
#   [{'Pennsylvania'}, {'Law', 'Light', 'Red'}],
#   [{'Law', 'Light', 'Red'}, {'Pennsylvania'}],
#   [{'Law', 'Light', 'Red'}, {'Pennsylvania’s'}, {'Tom', 'Wolf'}]],
#  'http://www.forwardhealthgroup.com/contact-us/': [[{'Madison,', 'WI'},
#    {'Contact', 'Us'}],
#   [{'Forward', 'Group', 'Health'}],
#   [{'Forward', 'Group', 'Health'}, {'Wisconsin'}],
#   [{'Contact', 'Us'}, {'Forward', 'Group', 'Health'}],
#   [{'Contact', 'Us'}, {'Forward', 'Group', 'Health'}]],
#  'https://homeremedyshop.com/5-home-remedies-for-broken-blood-vessels-on-face/': [[{'Blood',
#     'Broken',
#     'Vessels'},
#    {'Home', 'Remedies'}],
#   [{'spider', 'veins'}, {'face', 'region'}, {'Home', 'Remedies'}],
#   [{'Remedies'}, {'Broken', 'blood', 'vessels'}, {'spider', 'veins'}],
#   [{'Broken', 'blood', 'vessels'}, {'Home', 'Remedies'}, {'face', 'region'}],
#   [{'Blood', 'Broken', 'Face', 'Vessels', 'on'}, {'spider', 'veins'}]],
#  'https://www.richestnetworth.com/ludacris-net-worth/': [[{'Ludacris',
#     'Net',
#     'Worth'},
#    {'Georgia', 'State'},
#    {'RIAA'}],
#   [{'Ludacris'}, {'Net', 'Worth'}, {'Award', 'rapper', 'winning'}],
#   [{'Ludacris'}, {'Net', 'Worth'}, {'Illinois'}]],
#  'https://www.energydepot.com/RPUcom/library/HVAC012.asp': [[{'Closed',
#     'Heat',
#     'Loop',
#     'Pump',
#     'Source',
#     'Water'},
#    {'semi-decentralized', 'system'},
#    {'electrical', 'system'}],
#   [{'Closed', 'Loop', 'Source', 'Water'}, {'Heat', 'Pump'}],
#   [{'Closed', 'Loop'}, {'Source', 'Water'}, {'Heat', 'Pump'}],
#   [{'closed', 'heat', 'loop', 'pump', 'source', 'water'},
#    {'flexible', 'highly'},
#    {'semi-decentralized', 'system'}],
#   [{'Closed', 'Heat', 'Loop', 'Pump', 'Source', 'Water'},
#    {'approach', 'semi-decentralized', 'system'},
#    {'electrical', 'system'}]],
#  'http://sghistory.com/index.php?n=V.Vestal_Goodman': [[{'Goodman',
#     'V.Vestal'},
#    {'Gospel', 'Music'},
#    {'Opera', 'singer'}],
#   [{'Goodman', 'V.Vestal'},
#    {'Gospel', 'Music', 'Queen', 'The', 'of'},
#    {'Alabama'}],
#   [{'Goodman', 'Vestal'}, {'Gospel', 'Music', 'Queen', 'The', 'of'}],
#   [{'Goodman', 'Vestal'},
#    {'Gospel', 'Music', 'Queen', 'The', 'of'},
#    {'Mountain', 'Sand'}],
#   [{'Goodman', 'V.Vestal'},
#    {'Goodman', 'Howard'},
#    {'Fame', 'GMA', 'Hall', 'Of'}]],
#  'https://hbr.org/2007/01/courage-as-a-skill': [[{'Courage'}, {'Skill'}],
#   [{'Courage', 'Skill', 'a', 'as'}, {'K.', 'Kathleen', 'Reardon'}],
#   [{'Courage', 'Skill', 'a', 'as'}, {'spontaneously'}],
#   [{'president', 'vice'}, {'whistle'}, {'corruption'}],
#   [{'John', 'McCain'}, {'U.S.', 'senator'}]],
#  'http://www.medicaidoffice.net/arkansas-medicaid-office-mo3': [[{'ARKANSAS',
#     'MEDICAID',
#     'OFFICE'},
#    {'Arkansas', 'Medicaid', 'program'},
#    {'Medicaid', 'enrollment'}],
#   [{'MEDICAID', 'OFFICE'}, {'ARKANSAS'}, {'Arkansas', 'Medicaid', 'program'}],
#   [{'Medicaid', 'office'}, {'Arkansas'}],
#   [{'ARKANSAS', 'MEDICAID', 'OFFICE'},
#    {'Arkansas', 'Medicaid', 'eligibility'}],
#   [{'MEDICAID', 'OFFICE'}, {'Arkansas'}, {'care', 'rehabilitation-facility'}]],
#  'https://lymediseaseassociation.org/about-lyme/other-tick-borne-diseases/ehrlichiosis-anaplasmosis': [[{'ehrlichiosis'},
#    {'(HME)', 'Ehrlichiosis', 'Human', 'Monocytic'},
#    {'doxycycline'}],
#   [{'Association', 'Disease', 'Lyme'},
#    {'Anaplasmosis'},
#    {'Ehrlichia', 'bacterium'}],
#   [{'Anaplasmosis'}, {'Ehrlichiosis', 'Human', 'Monocytic'}, {'Symptoms'}],
#   [{'Ehrlichiosis'}, {'Anaplasmosis'}, {'Ehrlichiosis', 'Human', 'Monocytic'}],
#   [{'Ehrlichiosis/Anaplasmosis'}, {'Association', 'Disease', 'Lyme'}]],
#  'http://www.answers.com/Q/How_long_can_a_mediport_remain': [[{'mediport'},
#    {'bankruptcy'},
#    {'FCRA'}],
#   [{'mediport'}, {'FCRA'}],
#   [{'mediport'}, {'FCRA'}],
#   [{'mediport'}, {'FIELD', 'STERILE'}, {'CHLORHEXADINE', 'SOLUTION'}],
#   [{'mediport'}, {'FIELD', 'STERILE'}, {'CHLORHEXADINE', 'SOLUTION'}]],
#  'http://www.kiplinger.com/quiz/retirement/T046-S001-how-much-do-you-really-know-about-roth-iras/index.html': [[{'IRAs',
#     'Roth'},
#    {'income', 'tax-free'},
#    {'federal', 'rules', 'tax'}],
#   [{'IRAs', 'Roth'}, {'income', 'tax-free'}, {'federal', 'rules', 'tax'}],
#   [{'IRAs', 'Roth'}, {'income', 'tax-free'}, {'federal', 'rules', 'tax'}],
#   [{'IRAs', 'Roth'}, {'Kiplinger'}],
#   [{'IRAs'}, {'Roth', 'accounts'}, {'income', 'tax-free'}]],
#  'https://ghr.nlm.nih.gov/primer/mutationsanddisorders/genemutation': [[{'gene',
#     'mutation'},
#    {'DNA', 'sequence'},
#    {'DNA', 'block', 'building', 'single'}],
#   [{'gene', 'mutation'},
#    {'Hereditary', 'mutations'},
#    {'Somatic', 'mutations'}],
#   [{'gene', 'mutation'}, {'alteration', 'permanent'}, {'DNA', 'sequence'}],
#   [{'gene', 'mutation'}, {'DNA'}],
#   [{'gene', 'mutation'}, {'DNA', 'sequence'}, {'DNA', 'block', 'building'}]],
#  'https://www.digitaltrends.com/mobile/best-phablets/': [[{'phablet'},
#    {'smartphones'}],
#   [{'phablet'}, {'smartphones'}],
#   [{'phablet'}],
#   [{'best', 'smartphones'}, {'bezel-less'}],
#   [{'phablet'}, {'smartphones'}]],
#  'http://www.thetraveljunkie.info/2016/01/how-to-apply-for-schengen-tourist-visa.html': [[{'Apply',
#     'Schengen',
#     'Tourist',
#     'Visa',
#     'for'},
#    {'Filipinos'},
#    {'Global', 'VFS'}],
#   [{'Schengen', 'Tourist', 'Visa'}, {'Filipinos'}],
#   [{'Schengen'}, {'Tourist', 'Visa'}, {'Filipinos'}],
#   [{'Schengen', 'Tourist'}, {'Filipinos'}],
#   [{'Tourist', 'Visa'}, {'Filipinos'}]],
#  'https://www.phonelookup.com/1/803-273-4855': [[{'Office', 'Post', 'US'}],
#   [{'Office', 'Post', 'US'}, {'Heath', 'Springs'}],
#   [{'Office', 'Post', 'US'}],
#   [{'Office', 'Post', 'US'}],
#   [{'Office', 'Post', 'US'}]],
#  'https://www.wikihow.com/Stop-a-Nose-Bleed': [[{'Bleed', 'Nose'},
#    {'nasal', 'septum'}],
#   [{'Bleed', 'Nose'}, {'epistaxis'}, {'blood', 'vessels'}],
#   [{'Bleed', 'Nose'}, {'epistaxis'}, {'blood', 'vessels'}],
#   [{'Bleed', 'Nose'}, {'epistaxis,'}, {'allergies,', 'nasal'}],
#   [{'Blanc', 'Grenache'}, {'Bowlin,', 'Julia', 'MD'}]],
#  'http://reefkeeping.com/issues/2007-03/sj/index.php': [[{'Halide',
#     'Lamps',
#     'Metal'},
#    {'Ballasts'},
#    {'MH', 'lighting', 'systems,'}],
#   [{'Metal', 'halide'}, {'MH', 'lighting', 'system'}],
#   [{'Metal', 'halide'}],
#   [{'Halide', 'Lamps', 'Metal'}, {'Ballasts'}],
#   [{'Halide', 'Lamp', 'Metal'}, {'Ballasts'}]],
#  'https://www.docusearch.com/license-plate-search-how-to-search-license-plate-numbers-online.html': [[{'LICENSE',
#     'NUMBERS',
#     'PLATE'}],
#   [{'LICENSE', 'LOOKUP', 'PLATE'}],
#   [{'LICENSE', 'LOOKUP', 'PLATE'}],
#   [{'LICENSE', 'NUMBERS', 'PLATE'},
#    {'searches', '“free'},
#    {'results”', '“instant'}],
#   [{'LICENSE', 'NUMBERS', 'PLATE'},
#    {'instant', 'results'},
#    {'searches', 'unlimited'}]],
#  'https://www.fidelity.com/fund-screener/research.shtml': [[{'Funds',
#     'Mutual',
#     'Research'},
#    {'Fidelity'},
#    {'Fund', 'Picks'}],
#   [{'Funds', 'Mutual'}],
#   [{'Funds', 'Mutual'}],
#   [{'Funds', 'Mutual', 'Research'}, {'investment'}],
#   [{'Funds', 'Mutual', 'Research'}, {'Fidelity'}]],
#  'http://www.usmagazine.com/celebrity-news/news/new-details-surface-about-oj-simpsons-prison-life-w440310': [[{'Cleans',
#     'O.J.',
#     'Simpson'},
#    {'Equipment', 'Gym'},
#    {'Prison'}],
#   [{'Cleans', 'O.J.', 'Simpson'}, {'Equipment', 'Gym'}, {'Prison'}],
#   [{'O.J.', 'Simpson'}, {'Prison'}, {'Nevada'}],
#   [{'O.J.', 'Simpson'}, {'Gym'}, {'Prison'}],
#   [{'O.J.', 'Simpson'}, {'Equipment', 'Gym'}, {'Prison'}]],
#  'http://www.thefreedictionary.com/Ounce+(zoology)': [[{'leopard', 'snow'}],
#   [{'leopard', 'snow'}],
#   [{'leopard', 'snow'}],
#   [{'leopard', 'snow'}, {'Dictionary'}],
#   [{'leopard', 'snow'}]],
#  'http://acronyms.thefreedictionary.com/ICD-10': [[{'ICD-10'},
#    {'Definition'},
#    {'Dictionary'}],
#   [{'ICD-10'}, {'Definition'}],
#   [{'ICD-10'}, {'Definition'}],
#   [{'ICD-10'}, {'DEFINITION'}, {'Acronym'}],
#   [{'ICD-10'}]],
#  'https://prezi.com/m5tf4pe8ynuq/asch-conformity-experiment/': [[{'Asch',
#     'Conformity',
#     'Experiment'},
#    {'Primary', 'Research', 'Tool'},
#    {'Hypothesis,'}],
#   [{'Asch', 'Conformity', 'Experiment'}],
#   [{'Asch', 'Conformity', 'Experiment'}, {'Melani', 'Rajhkumar'}],
#   [{'Asch', 'Conformity', 'Experiment'}],
#   [{'Asch', 'Conformity', 'Experiment'}]],
#  'https://www.slideserve.com/tyrone/exploratory-sae': [[{'Exploratory', 'SAE'},
#    {'SlideServe'},
#    {'PPT', 'PowerPoint', 'Presentation'}],
#   [{'Exploratory', 'SAE'}, {'Agricultural'}],
#   [{'Exploratory', 'SAE'}, {'PPT', 'PowerPoint'}],
#   [{'Exploratory', 'SAE'}, {'PPT', 'PowerPoint'}],
#   [{'Exploratory', 'SAE'},
#    {'Agricultural', 'Experience'},
#    {'Agriculture', 'Application', 'Develop', 'Supervised', 'skills'}]],
#  'https://www.facebook.com/AfscmeLocal2822': [[{'Facebook'}]],
#  'http://www.aarp.org/work/social-security/info-07-2010/maximum_monthly_social_security_benefit.html': [[{'Security',
#     'Social'},
#    {'AARP'}],
#   [{'Security', 'Social'}, {'&', 'JOBS', 'WORK'}, {'AARP'}],
#   [{'Security', 'Social'}],
#   [{'Security', 'Social'}]]}
